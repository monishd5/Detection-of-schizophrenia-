# %%
pip install nibabel
# Out:
# ...
#      ---------------------------------------- 3.3/3.3 MB 1.1 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import nibabel as nib
import numpy as np
import cv2
import os

def extract_specific_slices(nifti_file, output_dir, slice_indices, resolution=(64, 64)):
    # Load NIFTI file
    image = nib.load(nifti_file)
    data = image.get_fdata()
    
    if not os.path.exists(output_dir):
        os.makedirs(output_dir, exist_ok=True)

    # Assuming data is in shape [X, Y, Z, Time]
    num_time_points = data.shape[3]
    
    for time_point in range(num_time_points):
        for z_slice in slice_indices:
            slice_data = data[:, :, int(z_slice), time_point]
            slice_resized = cv2.resize(slice_data.astype(np.float32), resolution, interpolation=cv2.INTER_LINEAR)
            slice_normalized = cv2.normalize(slice_resized, None, 0, 255, cv2.NORM_MINMAX).astype(np.uint8)
            output_path = os.path.join(output_dir, f'slice_{int(z_slice)}_time_{time_point}.png')
            cv2.imwrite(output_path, slice_normalized)

# Example usage
nifti_file = r'C:\preprocess\sub-A00000300\ses\func\sub-A00000300_ses-20110101_task-rest_bold_normalized.nii\a.nii'
output_dir = r'C:\Users\knaik\OneDrive\Desktop\forbiden'
# Example slice indices for important brain regions
slice_indices = [10, 20, 30, 40, 50]  # Adjust these indices based on your data
extract_specific_slices(nifti_file, output_dir, slice_indices)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_32972\2638009961.py in <module>
#      28 # Example slice indices for important brain regions
#      29 slice_indices = [10, 20, 30, 40, 50]  # Adjust these indices based on your data
# ---> 30 extract_specific_slices(nifti_file, output_dir, slice_indices)
#
# ~\AppData\Local\Temp\ipykernel_32972\2638009961.py in extract_specific_slices(nifti_file, output_dir, slice_indices, resolution)
#      13
#      14     # Assuming data is in shape [X, Y, Z, Time]
# ---> 15     num_time_points = data.shape[3]
#      16
#      17     for time_point in range(num_time_points):
#
# IndexError: tuple index out of range

# %%
# !pip install opencv-python
# Out:
# ...
#      -------------------------------------- 38.8/38.8 MB 326.9 kB/s eta 0:00:00
# ...

# %%
import nibabel as nib
import numpy as np
import cv2
import os

def extract_specific_slices(nifti_file, output_dir, slice_indices, resolution=(64, 64)):
    # Load NIFTI file
    image = nib.load(nifti_file)
    data = image.get_fdata()
    
    if not os.path.exists(output_dir):
        os.makedirs(output_dir, exist_ok=True)
    
    # Check if the data is 3D or 4D
    if len(data.shape) == 4:  # 4D data
        num_time_points = data.shape[3]
        for time_point in range(num_time_points):
            for z_slice in slice_indices:
                slice_data = data[:, :, int(z_slice), time_point]
                slice_resized = cv2.resize(slice_data.astype(np.float32), resolution, interpolation=cv2.INTER_LINEAR)
                slice_normalized = cv2.normalize(slice_resized, None, 0, 255, cv2.NORM_MINMAX).astype(np.uint8)
                output_path = os.path.join(output_dir, f'slice_{int(z_slice)}_time_{time_point}.png')
                cv2.imwrite(output_path, slice_normalized)
    elif len(data.shape) == 3:  # 3D data
        for z_slice in slice_indices:
            slice_data = data[:, :, int(z_slice)]
            slice_resized = cv2.resize(slice_data.astype(np.float32), resolution, interpolation=cv2.INTER_LINEAR)
            slice_normalized = cv2.normalize(slice_resized, None, 0, 255, cv2.NORM_MINMAX).astype(np.uint8)
            output_path = os.path.join(output_dir, f'slice_{int(z_slice)}.png')
            cv2.imwrite(output_path, slice_normalized)
    else:
        print("Unexpected data shape:", data.shape)

# Example usage
nifti_file = r'C:\preprocess\sub-A00000300\ses\func\sub-A00000300_ses-20110101_task-rest_bold_normalized.nii\a.nii'
output_dir = r'C:\Users\knaik\OneDrive\Desktop\forbiden'
#slice_indices = [10, 20, 30, 40, 50]  # Adjust these indices based on your data
slice_indices = list(range(0, 61, 2))[:30]  # This will select 30 slices starting from 0, every second slice

extract_specific_slices(nifti_file, output_dir, slice_indices)

# %%
import os
import nibabel as nib
import numpy as np
import cv2

def extract_specific_slices(nifti_file, output_dir, slice_indices, resolution=(64, 64)):
    # Load NIFTI file
    image = nib.load(nifti_file)
    data = image.get_fdata()
    
    if not os.path.exists(output_dir):
        os.makedirs(output_dir, exist_ok=True)
    
    # Check if the data is 3D or 4D
    if len(data.shape) == 4:
        num_time_points = data.shape[3]
        for time_point in range(num_time_points):
            for z_slice in slice_indices:
                slice_data = data[:, :, int(z_slice), time_point]
                slice_resized = cv2.resize(slice_data.astype(np.float32), resolution, interpolation=cv2.INTER_LINEAR)
                slice_normalized = cv2.normalize(slice_resized, None, 0, 255, cv2.NORM_MINMAX).astype(np.uint8)
                output_path = os.path.join(output_dir, f'slice_{int(z_slice)}_time_{time_point}.png')
                cv2.imwrite(output_path, slice_normalized)
    elif len(data.shape) == 3:
        for z_slice in slice_indices:
            slice_data = data[:, :, int(z_slice)]
            slice_resized = cv2.resize(slice_data.astype(np.float32), resolution, interpolation=cv2.INTER_LINEAR)
            slice_normalized = cv2.normalize(slice_resized, None, 0, 255, cv2.NORM_MINMAX).astype(np.uint8)
            output_path = os.path.join(output_dir, f'slice_{int(z_slice)}.png')
            cv2.imwrite(output_path, slice_normalized)
    else:
        print("Unexpected data shape:", data.shape)

# Path to the directory containing all subfolders
root_dir = r'C:\preprocess\normalized_files'
output_root = r'C:\Users\knaik\OneDrive\Desktop\forbiden\slicedbrain'

# Get list of all subdirectories
folders = [f.path for f in os.scandir(root_dir) if f.is_dir()]

# Loop through each folder and apply extract_specific_slices
for folder in folders:
    # Find the first .nii file in the folder
    for file in os.listdir(folder):
        if file.endswith('.nii') or file.endswith('.nii.gz'):
            nifti_file = os.path.join(folder, file)
            output_dir = os.path.join(output_root, os.path.basename(folder))
            slice_indices = list(range(0, 61, 2))[:30]  # Adjust slice indices as needed
            extract_specific_slices(nifti_file, output_dir, slice_indices)
            break  # Only process the first .nii file found
    else:
        print(f"No NIfTI file found in folder: {folder}")

# %%
import os
import nibabel as nib
import numpy as np
import cv2

def extract_specific_slices(nifti_file, output_dir, slice_indices, resolution=(64, 64)):
    # Load NIFTI file
    image = nib.load(nifti_file)
    data = image.get_fdata()
    
    if not os.path.exists(output_dir):
        os.makedirs(output_dir, exist_ok=True)
    
    # Check if the data is 3D or 4D
    if len(data.shape) == 4:
        num_time_points = data.shape[3]
        for time_point in range(num_time_points):
            for z_slice in slice_indices:
                slice_data = data[:, :, int(z_slice), time_point]
                slice_resized = cv2.resize(slice_data.astype(np.float32), resolution, interpolation=cv2.INTER_LINEAR)
                slice_normalized = cv2.normalize(slice_resized, None, 0, 255, cv2.NORM_MINMAX).astype(np.uint8)
                output_path = os.path.join(output_dir, f'slice_{int(z_slice)}_time_{time_point}.png')
                cv2.imwrite(output_path, slice_normalized)
    elif len(data.shape) == 3:
        for z_slice in slice_indices:
            slice_data = data[:, :, int(z_slice)]
            slice_resized = cv2.resize(slice_data.astype(np.float32), resolution, interpolation=cv2.INTER_LINEAR)
            slice_normalized = cv2.normalize(slice_resized, None, 0, 255, cv2.NORM_MINMAX).astype(np.uint8)
            output_path = os.path.join(output_dir, f'slice_{int(z_slice)}.png')
            cv2.imwrite(output_path, slice_normalized)
    else:
        print("Unexpected data shape:", data.shape)

# Path to the directory containing all subfolders
root_dir = r'C:\preprocess2\normalized_files'
output_root = r'C:\Users\knaik\OneDrive\Desktop\forbiden\slicedbrain'

# Get list of all subdirectories
folders = [f.path for f in os.scandir(root_dir) if f.is_dir()]

# Loop through each folder and apply extract_specific_slices
for folder in folders:
    # Find the first .nii file in the folder
    for file in os.listdir(folder):
        if file.endswith('.nii') or file.endswith('.nii.gz'):
            nifti_file = os.path.join(folder, file)
            output_dir = os.path.join(output_root, os.path.basename(folder))
            slice_indices = list(range(0, 61, 2))[:30]  # Adjust slice indices as needed
            extract_specific_slices(nifti_file, output_dir, slice_indices)
            break  # Only process the first .nii file found
    else:
        print(f"No NIfTI file found in folder: {folder}")

# %%
import os
import nibabel as nib
import numpy as np
import cv2

def extract_specific_slices(nifti_file, output_dir, slice_indices, resolution=(64, 64)):
    # Load NIFTI file
    image = nib.load(nifti_file)
    data = image.get_fdata()
    
    if not os.path.exists(output_dir):
        os.makedirs(output_dir, exist_ok=True)
    
    # Check if the data is 3D or 4D
    if len(data.shape) == 4:
        num_time_points = data.shape[3]
        for time_point in range(num_time_points):
            for z_slice in slice_indices:
                slice_data = data[:, :, int(z_slice), time_point]
                slice_resized = cv2.resize(slice_data.astype(np.float32), resolution, interpolation=cv2.INTER_LINEAR)
                slice_normalized = cv2.normalize(slice_resized, None, 0, 255, cv2.NORM_MINMAX).astype(np.uint8)
                output_path = os.path.join(output_dir, f'slice_{int(z_slice)}_time_{time_point}.png')
                cv2.imwrite(output_path, slice_normalized)
    elif len(data.shape) == 3:
        for z_slice in slice_indices:
            slice_data = data[:, :, int(z_slice)]
            slice_resized = cv2.resize(slice_data.astype(np.float32), resolution, interpolation=cv2.INTER_LINEAR)
            slice_normalized = cv2.normalize(slice_resized, None, 0, 255, cv2.NORM_MINMAX).astype(np.uint8)
            output_path = os.path.join(output_dir, f'slice_{int(z_slice)}.png')
            cv2.imwrite(output_path, slice_normalized)
    else:
        print("Unexpected data shape:", data.shape)

# Path to the directory containing all subfolders
root_dir = r'C:\preprocess3\normalized_files'
output_root = r'C:\Users\knaik\OneDrive\Desktop\forbiden\slicedbrain'

# Get list of all subdirectories
folders = [f.path for f in os.scandir(root_dir) if f.is_dir()]

# Loop through each folder and apply extract_specific_slices
for folder in folders:
    # Find the first .nii file in the folder
    for file in os.listdir(folder):
        if file.endswith('.nii') or file.endswith('.nii.gz'):
            nifti_file = os.path.join(folder, file)
            output_dir = os.path.join(output_root, os.path.basename(folder))
            slice_indices = list(range(0, 61, 2))[:30]  # Adjust slice indices as needed
            extract_specific_slices(nifti_file, output_dir, slice_indices)
            break  # Only process the first .nii file found
    else:
        print(f"No NIfTI file found in folder: {folder}")

# %%
import os
import nibabel as nib
import numpy as np
import cv2

def extract_specific_slices(nifti_file, output_dir, slice_indices, resolution=(64, 64)):
    # Load NIFTI file
    image = nib.load(nifti_file)
    data = image.get_fdata()
    
    if not os.path.exists(output_dir):
        os.makedirs(output_dir, exist_ok=True)
    
    # Check if the data is 3D or 4D
    if len(data.shape) == 4:
        num_time_points = data.shape[3]
        for time_point in range(num_time_points):
            for z_slice in slice_indices:
                slice_data = data[:, :, int(z_slice), time_point]
                slice_resized = cv2.resize(slice_data.astype(np.float32), resolution, interpolation=cv2.INTER_LINEAR)
                slice_normalized = cv2.normalize(slice_resized, None, 0, 255, cv2.NORM_MINMAX).astype(np.uint8)
                output_path = os.path.join(output_dir, f'slice_{int(z_slice)}_time_{time_point}.png')
                cv2.imwrite(output_path, slice_normalized)
    elif len(data.shape) == 3:
        for z_slice in slice_indices:
            slice_data = data[:, :, int(z_slice)]
            slice_resized = cv2.resize(slice_data.astype(np.float32), resolution, interpolation=cv2.INTER_LINEAR)
            slice_normalized = cv2.normalize(slice_resized, None, 0, 255, cv2.NORM_MINMAX).astype(np.uint8)
            output_path = os.path.join(output_dir, f'slice_{int(z_slice)}.png')
            cv2.imwrite(output_path, slice_normalized)
    else:
        print("Unexpected data shape:", data.shape)

# Path to the directory containing all subfolders
root_dir = r'C:\preprocess4\normalized_files'
output_root = r'C:\Users\knaik\OneDrive\Desktop\forbiden\slicedbrain'

# Get list of all subdirectories
folders = [f.path for f in os.scandir(root_dir) if f.is_dir()]

# Loop through each folder and apply extract_specific_slices
for folder in folders:
    # Find the first .nii file in the folder
    for file in os.listdir(folder):
        if file.endswith('.nii') or file.endswith('.nii.gz'):
            nifti_file = os.path.join(folder, file)
            output_dir = os.path.join(output_root, os.path.basename(folder))
            slice_indices = list(range(0, 61, 2))[:30]  # Adjust slice indices as needed
            extract_specific_slices(nifti_file, output_dir, slice_indices)
            break  # Only process the first .nii file found
    else:
        print(f"No NIfTI file found in folder: {folder}")

# %%
import os
import nibabel as nib
import numpy as np
import cv2

def extract_specific_slices(nifti_file, output_dir, slice_indices, resolution=(64, 64)):
    # Load NIFTI file
    image = nib.load(nifti_file)
    data = image.get_fdata()
    
    if not os.path.exists(output_dir):
        os.makedirs(output_dir, exist_ok=True)
    
    # Check if the data is 3D or 4D
    if len(data.shape) == 4:
        num_time_points = data.shape[3]
        for time_point in range(num_time_points):
            for z_slice in slice_indices:
                slice_data = data[:, :, z_slice, time_point]
                slice_resized = cv2.resize(slice_data.astype(np.float32), resolution, interpolation=cv2.INTER_LINEAR)
                slice_normalized = cv2.normalize(slice_resized, None, 0, 255, cv2.NORM_MINMAX).astype(np.uint8)
                output_path = os.path.join(output_dir, f'slice_{z_slice}_time_{time_point}.png')
                cv2.imwrite(output_path, slice_normalized)
    elif len(data.shape) == 3:
        for z_slice in slice_indices:
            slice_data = data[:, :, z_slice]
            slice_resized = cv2.resize(slice_data.astype(np.float32), resolution, interpolation=cv2.INTER_LINEAR)
            slice_normalized = cv2.normalize(slice_resized, None, 0, 255, cv2.NORM_MINMAX).astype(np.uint8)
            output_path = os.path.join(output_dir, f'slice_{z_slice}.png')
            cv2.imwrite(output_path, slice_normalized)
    else:
        print("Unexpected data shape:", data.shape)

# Path to the directory containing all subfolders
root_dir = r'C:\preprocess\normalized_files'
output_root = r'C:\Users\knaik\OneDrive\Desktop\forbiden\sliced61'

# Get list of all subdirectories
folders = [f.path for f in os.scandir(root_dir) if f.is_dir()]

# Loop through each folder and apply extract_specific_slices
for folder in folders:
    # Find the first .nii file in the folder
    for file in os.listdir(folder):
        if file.endswith('.nii') or file.endswith('.nii.gz'):
            nifti_file = os.path.join(folder, file)
            output_dir = os.path.join(output_root, os.path.basename(folder))
            slice_indices = list(range(61))  # Include all slices from 0 to 60
            extract_specific_slices(nifti_file, output_dir, slice_indices)
            break  # Only process the first .nii file found
    else:
        print(f"No NIfTI file found in folder: {folder}")

# %%
import os
import nibabel as nib
import numpy as np
import cv2

def extract_specific_slices(nifti_file, output_dir, slice_indices, resolution=(64, 64)):
    # Load NIFTI file
    image = nib.load(nifti_file)
    data = image.get_fdata()
    
    if not os.path.exists(output_dir):
        os.makedirs(output_dir, exist_ok=True)
    
    # Check if the data is 3D or 4D
    if len(data.shape) == 4:
        num_time_points = data.shape[3]
        for time_point in range(num_time_points):
            for z_slice in slice_indices:
                slice_data = data[:, :, z_slice, time_point]
                slice_resized = cv2.resize(slice_data.astype(np.float32), resolution, interpolation=cv2.INTER_LINEAR)
                slice_normalized = cv2.normalize(slice_resized, None, 0, 255, cv2.NORM_MINMAX).astype(np.uint8)
                output_path = os.path.join(output_dir, f'slice_{z_slice}_time_{time_point}.png')
                cv2.imwrite(output_path, slice_normalized)
    elif len(data.shape) == 3:
        for z_slice in slice_indices:
            slice_data = data[:, :, z_slice]
            slice_resized = cv2.resize(slice_data.astype(np.float32), resolution, interpolation=cv2.INTER_LINEAR)
            slice_normalized = cv2.normalize(slice_resized, None, 0, 255, cv2.NORM_MINMAX).astype(np.uint8)
            output_path = os.path.join(output_dir, f'slice_{z_slice}.png')
            cv2.imwrite(output_path, slice_normalized)
    else:
        print("Unexpected data shape:", data.shape)

# Path to the directory containing all subfolders
root_dir = r'C:\preprocess2\normalized_files'
output_root = r'C:\Users\knaik\OneDrive\Desktop\forbiden\sliced61'

# Get list of all subdirectories
folders = [f.path for f in os.scandir(root_dir) if f.is_dir()]

# Loop through each folder and apply extract_specific_slices
for folder in folders:
    # Find the first .nii file in the folder
    for file in os.listdir(folder):
        if file.endswith('.nii') or file.endswith('.nii.gz'):
            nifti_file = os.path.join(folder, file)
            output_dir = os.path.join(output_root, os.path.basename(folder))
            slice_indices = list(range(61))  # Include all slices from 0 to 60
            extract_specific_slices(nifti_file, output_dir, slice_indices)
            break  # Only process the first .nii file found
    else:
        print(f"No NIfTI file found in folder: {folder}")

# %%
import os
import nibabel as nib
import numpy as np
import cv2

def extract_specific_slices(nifti_file, output_dir, slice_indices, resolution=(64, 64)):
    # Load NIFTI file
    image = nib.load(nifti_file)
    data = image.get_fdata()
    
    if not os.path.exists(output_dir):
        os.makedirs(output_dir, exist_ok=True)
    
    # Check if the data is 3D or 4D
    if len(data.shape) == 4:
        num_time_points = data.shape[3]
        for time_point in range(num_time_points):
            for z_slice in slice_indices:
                slice_data = data[:, :, z_slice, time_point]
                slice_resized = cv2.resize(slice_data.astype(np.float32), resolution, interpolation=cv2.INTER_LINEAR)
                slice_normalized = cv2.normalize(slice_resized, None, 0, 255, cv2.NORM_MINMAX).astype(np.uint8)
                output_path = os.path.join(output_dir, f'slice_{z_slice}_time_{time_point}.png')
                cv2.imwrite(output_path, slice_normalized)
    elif len(data.shape) == 3:
        for z_slice in slice_indices:
            slice_data = data[:, :, z_slice]
            slice_resized = cv2.resize(slice_data.astype(np.float32), resolution, interpolation=cv2.INTER_LINEAR)
            slice_normalized = cv2.normalize(slice_resized, None, 0, 255, cv2.NORM_MINMAX).astype(np.uint8)
            output_path = os.path.join(output_dir, f'slice_{z_slice}.png')
            cv2.imwrite(output_path, slice_normalized)
    else:
        print("Unexpected data shape:", data.shape)

# Path to the directory containing all subfolders
root_dir = r'C:\preprocess3\normalized_files'
output_root = r'C:\Users\knaik\OneDrive\Desktop\forbiden\sliced61'

# Get list of all subdirectories
folders = [f.path for f in os.scandir(root_dir) if f.is_dir()]

# Loop through each folder and apply extract_specific_slices
for folder in folders:
    # Find the first .nii file in the folder
    for file in os.listdir(folder):
        if file.endswith('.nii') or file.endswith('.nii.gz'):
            nifti_file = os.path.join(folder, file)
            output_dir = os.path.join(output_root, os.path.basename(folder))
            slice_indices = list(range(61))  # Include all slices from 0 to 60
            extract_specific_slices(nifti_file, output_dir, slice_indices)
            break  # Only process the first .nii file found
    else:
        print(f"No NIfTI file found in folder: {folder}")

# %%
import os
import nibabel as nib
import numpy as np
import cv2

def extract_specific_slices(nifti_file, output_dir, slice_indices, resolution=(64, 64)):
    # Load NIFTI file
    image = nib.load(nifti_file)
    data = image.get_fdata()
    
    if not os.path.exists(output_dir):
        os.makedirs(output_dir, exist_ok=True)
    
    # Check if the data is 3D or 4D
    if len(data.shape) == 4:
        num_time_points = data.shape[3]
        for time_point in range(num_time_points):
            for z_slice in slice_indices:
                slice_data = data[:, :, z_slice, time_point]
                slice_resized = cv2.resize(slice_data.astype(np.float32), resolution, interpolation=cv2.INTER_LINEAR)
                slice_normalized = cv2.normalize(slice_resized, None, 0, 255, cv2.NORM_MINMAX).astype(np.uint8)
                output_path = os.path.join(output_dir, f'slice_{z_slice}_time_{time_point}.png')
                cv2.imwrite(output_path, slice_normalized)
    elif len(data.shape) == 3:
        for z_slice in slice_indices:
            slice_data = data[:, :, z_slice]
            slice_resized = cv2.resize(slice_data.astype(np.float32), resolution, interpolation=cv2.INTER_LINEAR)
            slice_normalized = cv2.normalize(slice_resized, None, 0, 255, cv2.NORM_MINMAX).astype(np.uint8)
            output_path = os.path.join(output_dir, f'slice_{z_slice}.png')
            cv2.imwrite(output_path, slice_normalized)
    else:
        print("Unexpected data shape:", data.shape)

# Path to the directory containing all subfolders
root_dir = r'C:\preprocess4\normalized_files'
output_root = r'C:\Users\knaik\OneDrive\Desktop\forbiden\sliced61'

# Get list of all subdirectories
folders = [f.path for f in os.scandir(root_dir) if f.is_dir()]

# Loop through each folder and apply extract_specific_slices
for folder in folders:
    # Find the first .nii file in the folder
    for file in os.listdir(folder):
        if file.endswith('.nii') or file.endswith('.nii.gz'):
            nifti_file = os.path.join(folder, file)
            output_dir = os.path.join(output_root, os.path.basename(folder))
            slice_indices = list(range(61))  # Include all slices from 0 to 60
            extract_specific_slices(nifti_file, output_dir, slice_indices)
            break  # Only process the first .nii file found
    else:
        print(f"No NIfTI file found in folder: {folder}")
